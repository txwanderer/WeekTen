# %%
import pandas as pd
import numpy as np

# %%
#download the class movie reviews from here:
#https://docs.google.com/spreadsheets/d/17rCJzmWxqvAu9rkpkgt4ToccIlY4A1Ffuu1W9X3B8Ag/
#then read that in as a pandas dataframe

# %%
M = pd.read_csv("MovieReviews.csv", index_col='Name')

# %%
def pearson(s1, s2):
    """Take two pd.Series objects and return a pearson correlation."""
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c ** 2) * np.sum(s2_c ** 2))

# %%
def get_recs(movie_name, M, num):

    import numpy as np
    reviews = []
    for title in M.columns:
        if title == movie_name:
            continue
        cor = pearson(M[movie_name], M[title])
        if np.isnan(cor):
            continue
        else:
            reviews.append((title, cor))
    1
    reviews.sort(key=lambda tup: tup[1], reverse=True)
    return reviews[:num]

# %% [markdown]
# ###Question 1:  What movie is most Similar to 'The fault in our stars' (60 pts)

# %%
recs = get_recs('The Fault in Our Stars', M, 1)
recs
# Out:
# [('How to Train your Dragon 2', 0.35284965832189968)]

# %% [markdown]
# ### Appears that "How to train your dragon 2" is the most "similar". :)

# %% [markdown]
# ###Question 2:  Which movie(s) would you most like to see, based on your classmates experience? (40 pts)

# %%
#HINTS...

#the movies I've seen
my_ratings = M.ix['Jared Knowles'].dropna()
#the movie I've rated the highest
my_ratings.sort(ascending=False)
#the name of the movie I've rated the highest
fav_movie = my_ratings.index[0]

myRecs = get_recs(fav_movie, M, 10)
myRecs
# Out:
# C:\Users\etrnl_000\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: sort is deprecated, use sort_values(inplace=True) for for INPLACE sorting
# [('Big Hero 6', 0.30210691278538199),
#  ('Transformers', 0.21482095034521259),
#  ('Malificent', 0.14495645441680338),
#  ('Divergent', 0.1281629245148653),
#  ('Interstellar', 0.11240759093221801),
#  ('The Lego Movie', 0.067255534405968834),
#  ('Godzilla', 0.049494549137343684),
#  ('The Hunger Games: Mockingjay - Part 1', 0.027016391046651777),
#  ('Guardians of the Galaxy', 0.0),
#  ('How to Train your Dragon 2', -0.0219286339726678)]

# %% [markdown]
# ### Looks like I would like to watch: Big Hero 6, Transformers, Divergent, Intersellar, Godzilla, The Hunger Games: Mockingjay - Part 1
# ### The movies that I did not mention I have already seen

# %% [markdown]
# ###Question 3: Bonus Question...  For all the movies you haven't seen, can you predict how you'd rate them using your the class reviews? (10 pts)

# %%
newFrame = M.copy(deep=True)
newFrame
# Out:
#                          American Sniper  \
# Name
# Mike                                 NaN
# HJ SONG                              NaN
# Ryan Hansen                          NaN
# Olumuyiwa Durojaiye                  NaN
# Charlie                              NaN
# Sina Tuy                             NaN
# Pavithra Shetty                      NaN
# Sara Collins                         NaN
# Jonathan Doll                        NaN
# saikiran reddy                         3
# Aishwarya reddy                      NaN
# Brant Mullinix                       NaN
# Sai Sampath                          NaN
# Suyendra                             NaN
# Sai Yallapragada                       5
# Akhilesh                             NaN
# Sundar Prasad                        NaN
# Evan Piercy                            4
# Jessica Fong                         NaN
# Onsiri Tapsarn                         3
# Anirudh Thota                        NaN
# Greg Werner                            5
# ...

# %%
newFrame = newFrame.fillna(0)
newFrame[newFrame != 0] = 1
newFrame
# Out:
#                          American Sniper  \
# Name
# Mike                                   0
# HJ SONG                                0
# Ryan Hansen                            0
# Olumuyiwa Durojaiye                    0
# Charlie                                0
# Sina Tuy                               0
# Pavithra Shetty                        0
# Sara Collins                           0
# Jonathan Doll                          0
# saikiran reddy                         1
# Aishwarya reddy                        0
# Brant Mullinix                         0
# Sai Sampath                            0
# Suyendra                               0
# Sai Yallapragada                       1
# Akhilesh                               0
# Sundar Prasad                          0
# Evan Piercy                            1
# Jessica Fong                           0
# Onsiri Tapsarn                         1
# Anirudh Thota                          0
# Greg Werner                            1
# ...

# %%
cooccurences = newFrame.T.dot(newFrame)
cooccurences
# Out:
#                                        American Sniper  \
# American Sniper                                     31
# The Hunger Games: Mockingjay - Part 1               21
# Guardians of the Galaxy                             24
# The Lego Movie                                      15
# The Hobbit                                          22
# Transformers                                        22
# Malificent                                          13
# Big Hero 6                                          11
# Godzilla                                            19
# Interstellar                                        21
# How to Train your Dragon 2                          18
# Gone Girl                                           19
# Divergent                                           17
# The Fault in Our Stars                               9
# Unbroken                                             5
# 300: Rise of an Empire                              26
#
# ...

# %%
my_ratings
# Out:
# Unbroken                      5
# Guardians of the Galaxy       5
# How to Train your Dragon 2    4
# Malificent                    4
# The Lego Movie                4
# Name: Jared Knowles, dtype: float64

# %%
test[''] = cooccurences.dot(my_ratings)
test
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-d7f69a61ff92> in <module>()
# ----> 1 test = cooccurences.dot(my_ratings.T)
#       2 test
#
# C:\Users\etrnl_000\Anaconda3\lib\site-packages\pandas\core\frame.py in dot(self, other)
#     700             if (len(common) > len(self.columns) or
#     701                     len(common) > len(other.index)):
# --> 702                 raise ValueError('matrices are not aligned')
#     703
#     704             left = self.reindex(columns=common, copy=False)
#
# ValueError: matrices are not aligned
